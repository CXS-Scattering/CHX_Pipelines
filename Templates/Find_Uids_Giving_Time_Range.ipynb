# %%
from pyCHX.chx_packages import *
# %matplotlib notebook
plt.rcParams.update({'figure.max_open_warning': 0})
plt.rcParams.update({ 'image.origin': 'lower'   })
plt.rcParams.update({ 'image.interpolation': 'none'   })
import pickle as cpk
from pyCHX.chx_xpcs_xsvs_jupyter_V1 import *
import pandas as pds

# %%
import datetime
START_TIME = time.mktime(  datetime.datetime(2019, 9, 30, 0,  30, 0,0).timetuple() ) 
STOP_TIME = time.mktime(  datetime.datetime( 2019, 10, 7, 10, 30, 0,0).timetuple() ) 
fuids, uids, sids, all_info = get_print_uids( START_TIME, STOP_TIME,return_all_info=True)
# Out:
#   0: uid = '3afd2f' ##Mon Sep 30 08:52:13 2019 #23286: SAXS for neat EPON for SAXS 0.5mm flat cell--  3afd2f18-b706-479c-818d-042f281cab33
#   1: uid = 'ada774' ##Mon Sep 30 09:02:50 2019 #23287: test for 15wt% graphene + nanoplatelets in EPON 828--  ada7741c-c31d-479d-8002-8953efb458a7
#   2: uid = 'dbc40c' ##Mon Sep 30 09:03:54 2019 #23288: T=.19  test for 15wt% graphene + nanoplatelets in EPON 828--  dbc40c23-a926-46e9-a7f7-c852e88cd02c
#   3: uid = '6bbcd8' ##Mon Sep 30 09:06:13 2019 #23289: T=.036  test for 15wt% graphene + nanoplatelets in EPON 828--  6bbcd82b-62dc-44b0-99cb-68e74af5d370
#   4: uid = '382829' ##Mon Sep 30 09:08:20 2019 #23290: T=.036  test for 15wt% graphene + nanoplatelets in EPON 828--  382829c6-092a-4471-a333-3aeb30cc889a
#   5: uid = '3c75ac' ##Mon Sep 30 09:10:04 2019 #23291: T=.0068  test for 15wt% graphene + nanoplatelets in EPON 828--  3c75ac01-6206-4b1b-b68c-eeb46bbfe27b
# ...

# %%
N = len(fuids)
for i in range(N):
    try:
        print( i, fuids[i], db[ fuids[i]  ]['start']['T_yoke'] )
    except:
        pass
# Out:
# 0 3afd2f18-b706-479c-818d-042f281cab33 16.591
# 1 ada7741c-c31d-479d-8002-8953efb458a7 16.591
# 2 dbc40c23-a926-46e9-a7f7-c852e88cd02c 16.591
# 3 6bbcd82b-62dc-44b0-99cb-68e74af5d370 16.591
# 4 382829c6-092a-4471-a333-3aeb30cc889a 16.591
# 5 3c75ac01-6206-4b1b-b68c-eeb46bbfe27b 16.591
# 6 52be9738-5ceb-4460-8215-67900be252f7 16.591
# 22 76f84e1e-62e6-4251-812a-ef0f9c6d36b7 16.591
# 23 31930c82-f001-48f0-a45a-96afb68111ea 16.591
# 24 004e37f8-fdb3-498d-a7db-87691c85c6be 16.591
# 25 8addbe25-54b7-40d8-8837-5148056e17a5 16.591
# 26 42d9109f-1660-43b7-b4d7-e4f6f87789b2 16.591
# 27 51b901c3-0fed-4329-8974-3d2b9a755435 16.591
# 28 963a699a-bd3c-49f4-9e19-ef72603f489d 16.591
# 29 ed0796ea-d587-4b71-a58c-55e79e62bddc 16.591
# 30 e6144f66-cd6d-4903-a7f6-6999c7379984 16.591
# 31 f7f3f01a-b64c-457e-89af-a2ed5c2293c3 16.591
# 32 49085649-66a1-46a7-bfee-c0fe220d5d8b 16.591
# 33 f6ca8467-260b-4512-ab45-874afba8f0fd 16.591
# 34 8af07495-2f9c-4873-8195-59f339cd431c 16.591
# ...
